# %%
anzahl = int(input("Wie viele Schüler gibt es? "))  
namen = []
noten = []

for i in range(anzahl):
    name = input(f"Name von Schüler {i+1}: ")
    note = int(input(f"Note von {name}: "))
    namen.append(name)
    noten.append(note)

print("\nAlle Schüler:")
for i in range(anzahl):
    print(f"{namen[i]} -> {noten[i]}") 

#Durchschnittsnote
durchschnitt = sum(noten) / len(noten)
print("Durchschnittsnote:", durchschnitt)

#Beste Note
beste_note = min(noten)
bester_schueler = namen[noten.index(beste_note)]
print("Beste Note:", bester_schueler, "mit", beste_note)

#Schlechteste Note
schlechteste_note = max(noten)
schlechtester_schueler = namen[noten.index(schlechteste_note)]
print("Schlechteste Note:", schlechtester_schueler, "mit", schlechteste_note)

# %%
import random

held = 10
monster = 10

while held > 0 and monster > 0:
    schaden = random.randint(1, 10)
    monster -= schaden
    print("Held greift an! Monster verliert", schaden, "Punkte. Monster hat noch", monster, "Leben.")

    if monster <= 0:
        print("Der Held hat gewonnen!")
        break

    schaden = random.randint(1, 10)
    held -= schaden
    print("Monster greift an! Held verliert", schaden, "Punkte. Held hat noch", held, "Leben.")

    if held <= 0:
        print("Das Monster hat gewonnen!")
        break

# %%
import random

held = 10
monster = 10

while held > 0 and monster > 0:
    # Held greift an
    schaden = random.randint(1, 10)
    monster -= schaden
    if monster <= 0:
        monster = 0
        print("Held greift an! Monster verliert", schaden, "Punkte. Monster ist tot!")
        print("Der Held hat gewonnen!")
        break
    else:
        print("Held greift an! Monster verliert", schaden, "Punkte. Monster hat noch", monster, "Leben.")

    # Monster greift zurück
    schaden = random.randint(1, 10)
    held -= schaden
    if held <= 0:
        held = 0
        print("Monster greift an! Held verliert", schaden, "Punkte. Held ist tot!")
        print("Das Monster hat gewonnen!")
        break
    else:
        print("Monster greift an! Held verliert", schaden, "Punkte. Held hat noch", held, "Leben.")
