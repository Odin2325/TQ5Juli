# %% [markdown]
# # Python-Projekt: Temporäre Dateien löschen mit Python
#
# ## Lernziele
# - Dateien in einem Ordner suchen
# - Dateiendungen prüfen (Filter auf .tmp und .log)
# - Dateien mit Python löschen
# - Fehlerbehandlung einbauen
# - Nützliches System-Tool entwickeln

# %% [markdown]
# ## Schritt 1 – „Hallo Cleanup“
#
# ### Theorie:
# Bevor wir anfangen, lassen wir das Programm starten.
#
# ### Beispielcode:
# ```python
# print("Cleanup-Programm gestartet!")
# ```
#
# ### Übung:
# 1. Schreibe ein Programm, das beim Start „Cleanup gestartet“ und am Ende „Cleanup beendet“ ausgibt.
# 2. Ergänze dein Programm so, dass dein Name und das aktuelle Datum angezeigt werden.

# %%
import datetime

print('Cleanup gestartet!')
print('Gestartet von Ron um', datetime.datetime.now().strftime('%Y-%m-%d'))

# TODO: Logik implementieren

print('Cleanup beendet!')
# Out:
# Cleanup gestartet!
# Gestartet von Ron um 2025-09-12
# Cleanup beendet!

# %% [markdown]
# ## Schritt 2 – Dateien im Ordner auflisten
#
# ### Theorie:
# Mit os.walk können wir alle Dateien in einem Verzeichnis und seinen Unterordnern durchlaufen.
#
# ### Beispielcode:
# ```python
# import os
#
# target_dir = "/home/user/temp"  # oder
# "C:\\Users\\Rico\\AppData\\Local\\Temp"
#
# for root, dirs, files in os.walk(target_dir):
#     for file in files:
#         print(file)
# ```
#
# ### Übung:
# 1. Liste alle Dateien in deinem Temp-Ordner auf.
# 2. Ändere den Pfad so, dass du einen eigenen Test-Ordner mit Dateien verwendest.

# %%
import os

targetdir = 'C:\\Users\\mytq\\AppData\\Local\\Temp'

for root, dirs, files in os.walk(targetdir):
    for file in files:
        print(f"Gefundene Datei: {file} im Verzeichnis {root}")
# Out:
# Gefundene Datei: 605f9d22-3c02-4f4a-9c37-60bc9eb17fc4.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2
# Gefundene Datei: c71b402e-2487-47cd-8ac5-9ab44e95727e.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2
# Gefundene Datei: exthost-f72640.cpuprofile im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2
# Gefundene Datei: Setup Log 2025-09-12 #001.txt im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2
# Gefundene Datei: vscode-inno-updater-1757657012.log im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2
# Gefundene Datei: builtins-8948-n7Qfq3bU3bHy-.py im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\pyright-8948-6WASkbuSHj9j
# Gefundene Datei: cancellation-bg-1.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1001.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1003.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1005.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1007.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1009.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-101.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1011.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1013.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1015.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1017.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1019.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1021.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1023.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1025.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1027.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1029.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-103.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1031.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1033.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1035.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1037.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1039.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1041.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1043.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1045.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1047.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1049.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-105.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1051.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1053.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1055.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1057.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1059.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1061.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1063.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1065.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1067.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1069.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-107.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1071.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1073.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1075.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1077.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1079.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1081.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1083.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1085.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1087.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1089.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-109.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1091.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1093.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1095.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1097.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1099.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-11.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1101.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1103.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1105.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1107.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1109.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-111.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1111.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1113.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1115.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1117.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1119.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1121.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1123.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1125.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1127.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1129.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-113.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1131.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1133.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1135.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1137.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1139.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1141.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1143.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-1145.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-115.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-117.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-119.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-121.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-123.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-125.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-129.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-13.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-131.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-133.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-135.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-137.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-139.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-141.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-143.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-145.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-147.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-149.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-15.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-151.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-153.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-155.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-157.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-159.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-161.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-163.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-165.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-167.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-169.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-17.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-171.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-173.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-175.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-177.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-179.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-181.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-183.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-185.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-187.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-189.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-19.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-191.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-193.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-195.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-197.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-199.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-201.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-203.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-205.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-207.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-209.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-21.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-211.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-213.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-215.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-217.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-219.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-221.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-223.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-225.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-227.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-229.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-23.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-231.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-233.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-235.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-237.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-239.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-241.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-243.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-245.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-247.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-249.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-25.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-251.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-253.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-255.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-257.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-259.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-261.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-263.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-265.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-267.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-269.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-27.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-271.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-273.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-275.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-277.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-279.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-281.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-283.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-285.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-287.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-289.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-29.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-291.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-293.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-295.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-297.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-299.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-3.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-301.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-303.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-305.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-307.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-309.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-31.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-311.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-313.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-315.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-317.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-319.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-321.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-323.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-325.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-327.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-329.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-33.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-331.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-333.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-335.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-337.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-339.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-341.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-343.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-345.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-347.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-349.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-35.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-351.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-353.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-355.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-357.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-359.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-361.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-363.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-365.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-367.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-369.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-37.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-371.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-373.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-375.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-377.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-379.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-381.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-383.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-385.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-387.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-389.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-39.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-391.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-393.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-395.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-397.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-399.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-401.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-403.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-405.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-407.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-409.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-41.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-411.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-413.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-415.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-417.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-419.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-421.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-423.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-425.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-427.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-429.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-43.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-431.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-433.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-435.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-437.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-439.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-441.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-443.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-445.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-447.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-449.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-45.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-451.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-453.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-455.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-457.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-459.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-461.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-463.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-465.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-467.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-469.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-47.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-471.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# ...
# Gefundene Datei: cancellation-bg-835.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-837.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-839.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-841.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-843.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-845.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-847.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-849.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-85.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-851.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-853.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-855.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-857.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-859.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-861.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-863.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-865.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-867.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-869.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-87.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-871.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-873.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-875.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-877.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-879.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-881.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-883.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-885.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-887.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-889.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-89.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-891.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-893.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-895.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-897.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-899.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-9.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-901.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-903.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-905.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-907.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-909.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-91.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-911.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-913.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-915.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-917.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-919.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-921.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-923.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-925.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-927.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-929.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-93.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-931.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-933.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-935.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-937.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-939.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-941.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-943.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-945.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-947.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-949.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-95.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-951.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-953.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-955.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-957.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-959.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-961.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-963.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-965.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-967.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-969.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-97.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-971.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-973.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-975.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-977.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-979.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-981.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-983.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-985.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-987.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-989.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-99.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-991.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-993.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-995.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-997.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: cancellation-bg-999.tmp im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\python-languageserver-cancellation\f34c383b230e519043772a7e75cbbaf5d7fab7c81d
# Gefundene Datei: dotnet-suggest-registration-git-credential-manager, Version=2.6.1.0, Culture=neutral, PublicKeyToken=null im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\system-commandline-sentinel-files
# Gefundene Datei: CodeSetup-stable-f220831ea2d946c0dcb0f3eaa480eb435a2c1260.exe im Verzeichnis C:\Users\mytq\AppData\Local\Temp\2\vscode-stable-user-x64

# %% [markdown]
# ## Schritt 3 – Dateiendungen prüfen
#
# ### Theorie:
# Wir wollen nur bestimmte Dateitypen löschen – hier .tmp und .log Dateien.
#
# ### Beispielcode:
# ```python
# if file.endswith(".tmp") or file.endswith(".log"):
#     print(f"{file} wird gelöscht.")
# ```
#
# ### Übung:
# 1. Ergänze deinen Code so, dass nur .tmp und .log angezeigt werden.
# 2. Erzeuge eigene Testdateien (z. B. test1.tmp, test2.log, behalten.txt) und teste dein Programm.

# %%
import os

targetdir = 'C:\\Users\\mytq\\AppData\\Local\\Temp'

for root, dirs, files in os.walk(targetdir):
    for file in files:
        if file.endswith('.tmp') or file.endswith('.log'):
            print(f'{file} wird gelöscht.')
# Out:
# 605f9d22-3c02-4f4a-9c37-60bc9eb17fc4.tmp wird gelöscht.
# c71b402e-2487-47cd-8ac5-9ab44e95727e.tmp wird gelöscht.
# vscode-inno-updater-1757657012.log wird gelöscht.
# cancellation-bg-1.tmp wird gelöscht.
# cancellation-bg-1001.tmp wird gelöscht.
# cancellation-bg-1003.tmp wird gelöscht.
# cancellation-bg-1005.tmp wird gelöscht.
# cancellation-bg-1007.tmp wird gelöscht.
# cancellation-bg-1009.tmp wird gelöscht.
# cancellation-bg-101.tmp wird gelöscht.
# cancellation-bg-1011.tmp wird gelöscht.
# cancellation-bg-1013.tmp wird gelöscht.
# cancellation-bg-1015.tmp wird gelöscht.
# cancellation-bg-1017.tmp wird gelöscht.
# cancellation-bg-1019.tmp wird gelöscht.
# cancellation-bg-1021.tmp wird gelöscht.
# cancellation-bg-1023.tmp wird gelöscht.
# cancellation-bg-1025.tmp wird gelöscht.
# cancellation-bg-1027.tmp wird gelöscht.
# cancellation-bg-1029.tmp wird gelöscht.
# cancellation-bg-103.tmp wird gelöscht.
# cancellation-bg-1031.tmp wird gelöscht.
# cancellation-bg-1033.tmp wird gelöscht.
# cancellation-bg-1035.tmp wird gelöscht.
# cancellation-bg-1037.tmp wird gelöscht.
# cancellation-bg-1039.tmp wird gelöscht.
# cancellation-bg-1041.tmp wird gelöscht.
# cancellation-bg-1043.tmp wird gelöscht.
# cancellation-bg-1045.tmp wird gelöscht.
# cancellation-bg-1047.tmp wird gelöscht.
# cancellation-bg-1049.tmp wird gelöscht.
# cancellation-bg-105.tmp wird gelöscht.
# cancellation-bg-1051.tmp wird gelöscht.
# cancellation-bg-1053.tmp wird gelöscht.
# cancellation-bg-1055.tmp wird gelöscht.
# cancellation-bg-1057.tmp wird gelöscht.
# cancellation-bg-1059.tmp wird gelöscht.
# cancellation-bg-1061.tmp wird gelöscht.
# cancellation-bg-1063.tmp wird gelöscht.
# cancellation-bg-1065.tmp wird gelöscht.
# cancellation-bg-1067.tmp wird gelöscht.
# cancellation-bg-1069.tmp wird gelöscht.
# cancellation-bg-107.tmp wird gelöscht.
# cancellation-bg-1071.tmp wird gelöscht.
# cancellation-bg-1073.tmp wird gelöscht.
# cancellation-bg-1075.tmp wird gelöscht.
# cancellation-bg-1077.tmp wird gelöscht.
# cancellation-bg-1079.tmp wird gelöscht.
# cancellation-bg-1081.tmp wird gelöscht.
# cancellation-bg-1083.tmp wird gelöscht.
# cancellation-bg-1085.tmp wird gelöscht.
# cancellation-bg-1087.tmp wird gelöscht.
# cancellation-bg-1089.tmp wird gelöscht.
# cancellation-bg-109.tmp wird gelöscht.
# cancellation-bg-1091.tmp wird gelöscht.
# cancellation-bg-1093.tmp wird gelöscht.
# cancellation-bg-1095.tmp wird gelöscht.
# cancellation-bg-1097.tmp wird gelöscht.
# cancellation-bg-1099.tmp wird gelöscht.
# cancellation-bg-11.tmp wird gelöscht.
# cancellation-bg-1101.tmp wird gelöscht.
# cancellation-bg-1103.tmp wird gelöscht.
# cancellation-bg-1105.tmp wird gelöscht.
# cancellation-bg-1107.tmp wird gelöscht.
# cancellation-bg-1109.tmp wird gelöscht.
# cancellation-bg-111.tmp wird gelöscht.
# cancellation-bg-1111.tmp wird gelöscht.
# cancellation-bg-1113.tmp wird gelöscht.
# cancellation-bg-1115.tmp wird gelöscht.
# cancellation-bg-1117.tmp wird gelöscht.
# cancellation-bg-1119.tmp wird gelöscht.
# cancellation-bg-1121.tmp wird gelöscht.
# cancellation-bg-1123.tmp wird gelöscht.
# cancellation-bg-1125.tmp wird gelöscht.
# cancellation-bg-1127.tmp wird gelöscht.
# cancellation-bg-1129.tmp wird gelöscht.
# cancellation-bg-113.tmp wird gelöscht.
# cancellation-bg-1131.tmp wird gelöscht.
# cancellation-bg-1133.tmp wird gelöscht.
# cancellation-bg-1135.tmp wird gelöscht.
# cancellation-bg-1137.tmp wird gelöscht.
# cancellation-bg-1139.tmp wird gelöscht.
# cancellation-bg-1141.tmp wird gelöscht.
# cancellation-bg-1143.tmp wird gelöscht.
# cancellation-bg-1145.tmp wird gelöscht.
# cancellation-bg-1147.tmp wird gelöscht.
# cancellation-bg-1149.tmp wird gelöscht.
# cancellation-bg-115.tmp wird gelöscht.
# cancellation-bg-1151.tmp wird gelöscht.
# cancellation-bg-1153.tmp wird gelöscht.
# cancellation-bg-1155.tmp wird gelöscht.
# cancellation-bg-1157.tmp wird gelöscht.
# cancellation-bg-1159.tmp wird gelöscht.
# cancellation-bg-1161.tmp wird gelöscht.
# cancellation-bg-1163.tmp wird gelöscht.
# cancellation-bg-1165.tmp wird gelöscht.
# cancellation-bg-1167.tmp wird gelöscht.
# cancellation-bg-1169.tmp wird gelöscht.
# cancellation-bg-117.tmp wird gelöscht.
# cancellation-bg-1171.tmp wird gelöscht.
# cancellation-bg-1173.tmp wird gelöscht.
# cancellation-bg-1175.tmp wird gelöscht.
# cancellation-bg-1177.tmp wird gelöscht.
# cancellation-bg-1179.tmp wird gelöscht.
# cancellation-bg-1181.tmp wird gelöscht.
# cancellation-bg-119.tmp wird gelöscht.
# cancellation-bg-121.tmp wird gelöscht.
# cancellation-bg-123.tmp wird gelöscht.
# cancellation-bg-125.tmp wird gelöscht.
# cancellation-bg-129.tmp wird gelöscht.
# cancellation-bg-13.tmp wird gelöscht.
# cancellation-bg-131.tmp wird gelöscht.
# cancellation-bg-133.tmp wird gelöscht.
# cancellation-bg-135.tmp wird gelöscht.
# cancellation-bg-137.tmp wird gelöscht.
# cancellation-bg-139.tmp wird gelöscht.
# cancellation-bg-141.tmp wird gelöscht.
# cancellation-bg-143.tmp wird gelöscht.
# cancellation-bg-145.tmp wird gelöscht.
# cancellation-bg-147.tmp wird gelöscht.
# cancellation-bg-149.tmp wird gelöscht.
# cancellation-bg-15.tmp wird gelöscht.
# cancellation-bg-151.tmp wird gelöscht.
# cancellation-bg-153.tmp wird gelöscht.
# cancellation-bg-155.tmp wird gelöscht.
# cancellation-bg-157.tmp wird gelöscht.
# cancellation-bg-159.tmp wird gelöscht.
# cancellation-bg-161.tmp wird gelöscht.
# cancellation-bg-163.tmp wird gelöscht.
# cancellation-bg-165.tmp wird gelöscht.
# cancellation-bg-167.tmp wird gelöscht.
# cancellation-bg-169.tmp wird gelöscht.
# cancellation-bg-17.tmp wird gelöscht.
# cancellation-bg-171.tmp wird gelöscht.
# cancellation-bg-173.tmp wird gelöscht.
# cancellation-bg-175.tmp wird gelöscht.
# cancellation-bg-177.tmp wird gelöscht.
# cancellation-bg-179.tmp wird gelöscht.
# cancellation-bg-181.tmp wird gelöscht.
# cancellation-bg-183.tmp wird gelöscht.
# cancellation-bg-185.tmp wird gelöscht.
# cancellation-bg-187.tmp wird gelöscht.
# cancellation-bg-189.tmp wird gelöscht.
# cancellation-bg-19.tmp wird gelöscht.
# cancellation-bg-191.tmp wird gelöscht.
# cancellation-bg-193.tmp wird gelöscht.
# cancellation-bg-195.tmp wird gelöscht.
# cancellation-bg-197.tmp wird gelöscht.
# cancellation-bg-199.tmp wird gelöscht.
# cancellation-bg-201.tmp wird gelöscht.
# cancellation-bg-203.tmp wird gelöscht.
# cancellation-bg-205.tmp wird gelöscht.
# cancellation-bg-207.tmp wird gelöscht.
# cancellation-bg-209.tmp wird gelöscht.
# cancellation-bg-21.tmp wird gelöscht.
# cancellation-bg-211.tmp wird gelöscht.
# cancellation-bg-213.tmp wird gelöscht.
# cancellation-bg-215.tmp wird gelöscht.
# cancellation-bg-217.tmp wird gelöscht.
# cancellation-bg-219.tmp wird gelöscht.
# cancellation-bg-221.tmp wird gelöscht.
# cancellation-bg-223.tmp wird gelöscht.
# cancellation-bg-225.tmp wird gelöscht.
# cancellation-bg-227.tmp wird gelöscht.
# cancellation-bg-229.tmp wird gelöscht.
# cancellation-bg-23.tmp wird gelöscht.
# cancellation-bg-231.tmp wird gelöscht.
# cancellation-bg-233.tmp wird gelöscht.
# cancellation-bg-235.tmp wird gelöscht.
# cancellation-bg-237.tmp wird gelöscht.
# cancellation-bg-239.tmp wird gelöscht.
# cancellation-bg-241.tmp wird gelöscht.
# cancellation-bg-243.tmp wird gelöscht.
# cancellation-bg-245.tmp wird gelöscht.
# cancellation-bg-247.tmp wird gelöscht.
# cancellation-bg-249.tmp wird gelöscht.
# cancellation-bg-25.tmp wird gelöscht.
# cancellation-bg-251.tmp wird gelöscht.
# cancellation-bg-253.tmp wird gelöscht.
# cancellation-bg-255.tmp wird gelöscht.
# cancellation-bg-257.tmp wird gelöscht.
# cancellation-bg-259.tmp wird gelöscht.
# cancellation-bg-261.tmp wird gelöscht.
# cancellation-bg-263.tmp wird gelöscht.
# cancellation-bg-265.tmp wird gelöscht.
# cancellation-bg-267.tmp wird gelöscht.
# cancellation-bg-269.tmp wird gelöscht.
# cancellation-bg-27.tmp wird gelöscht.
# cancellation-bg-271.tmp wird gelöscht.
# cancellation-bg-273.tmp wird gelöscht.
# cancellation-bg-275.tmp wird gelöscht.
# cancellation-bg-277.tmp wird gelöscht.
# cancellation-bg-279.tmp wird gelöscht.
# cancellation-bg-281.tmp wird gelöscht.
# cancellation-bg-283.tmp wird gelöscht.
# cancellation-bg-285.tmp wird gelöscht.
# cancellation-bg-287.tmp wird gelöscht.
# cancellation-bg-289.tmp wird gelöscht.
# cancellation-bg-29.tmp wird gelöscht.
# cancellation-bg-291.tmp wird gelöscht.
# cancellation-bg-293.tmp wird gelöscht.
# cancellation-bg-295.tmp wird gelöscht.
# cancellation-bg-297.tmp wird gelöscht.
# cancellation-bg-299.tmp wird gelöscht.
# cancellation-bg-3.tmp wird gelöscht.
# cancellation-bg-301.tmp wird gelöscht.
# cancellation-bg-303.tmp wird gelöscht.
# cancellation-bg-305.tmp wird gelöscht.
# cancellation-bg-307.tmp wird gelöscht.
# cancellation-bg-309.tmp wird gelöscht.
# cancellation-bg-31.tmp wird gelöscht.
# cancellation-bg-311.tmp wird gelöscht.
# cancellation-bg-313.tmp wird gelöscht.
# cancellation-bg-315.tmp wird gelöscht.
# cancellation-bg-317.tmp wird gelöscht.
# cancellation-bg-319.tmp wird gelöscht.
# cancellation-bg-321.tmp wird gelöscht.
# cancellation-bg-323.tmp wird gelöscht.
# cancellation-bg-325.tmp wird gelöscht.
# cancellation-bg-327.tmp wird gelöscht.
# cancellation-bg-329.tmp wird gelöscht.
# cancellation-bg-33.tmp wird gelöscht.
# cancellation-bg-331.tmp wird gelöscht.
# cancellation-bg-333.tmp wird gelöscht.
# cancellation-bg-335.tmp wird gelöscht.
# cancellation-bg-337.tmp wird gelöscht.
# cancellation-bg-339.tmp wird gelöscht.
# cancellation-bg-341.tmp wird gelöscht.
# cancellation-bg-343.tmp wird gelöscht.
# cancellation-bg-345.tmp wird gelöscht.
# cancellation-bg-347.tmp wird gelöscht.
# cancellation-bg-349.tmp wird gelöscht.
# cancellation-bg-35.tmp wird gelöscht.
# cancellation-bg-351.tmp wird gelöscht.
# cancellation-bg-353.tmp wird gelöscht.
# cancellation-bg-355.tmp wird gelöscht.
# cancellation-bg-357.tmp wird gelöscht.
# cancellation-bg-359.tmp wird gelöscht.
# cancellation-bg-361.tmp wird gelöscht.
# cancellation-bg-363.tmp wird gelöscht.
# cancellation-bg-365.tmp wird gelöscht.
# cancellation-bg-367.tmp wird gelöscht.
# cancellation-bg-369.tmp wird gelöscht.
# cancellation-bg-37.tmp wird gelöscht.
# cancellation-bg-371.tmp wird gelöscht.
# cancellation-bg-373.tmp wird gelöscht.
# cancellation-bg-375.tmp wird gelöscht.
# cancellation-bg-377.tmp wird gelöscht.
# cancellation-bg-379.tmp wird gelöscht.
# cancellation-bg-381.tmp wird gelöscht.
# cancellation-bg-383.tmp wird gelöscht.
# cancellation-bg-385.tmp wird gelöscht.
# cancellation-bg-387.tmp wird gelöscht.
# cancellation-bg-389.tmp wird gelöscht.
# cancellation-bg-39.tmp wird gelöscht.
# cancellation-bg-391.tmp wird gelöscht.
# cancellation-bg-393.tmp wird gelöscht.
# cancellation-bg-395.tmp wird gelöscht.
# cancellation-bg-397.tmp wird gelöscht.
# cancellation-bg-399.tmp wird gelöscht.
# cancellation-bg-401.tmp wird gelöscht.
# cancellation-bg-403.tmp wird gelöscht.
# cancellation-bg-405.tmp wird gelöscht.
# cancellation-bg-407.tmp wird gelöscht.
# cancellation-bg-409.tmp wird gelöscht.
# cancellation-bg-41.tmp wird gelöscht.
# cancellation-bg-411.tmp wird gelöscht.
# cancellation-bg-413.tmp wird gelöscht.
# cancellation-bg-415.tmp wird gelöscht.
# cancellation-bg-417.tmp wird gelöscht.
# cancellation-bg-419.tmp wird gelöscht.
# cancellation-bg-421.tmp wird gelöscht.
# cancellation-bg-423.tmp wird gelöscht.
# cancellation-bg-425.tmp wird gelöscht.
# cancellation-bg-427.tmp wird gelöscht.
# cancellation-bg-429.tmp wird gelöscht.
# cancellation-bg-43.tmp wird gelöscht.
# cancellation-bg-431.tmp wird gelöscht.
# cancellation-bg-433.tmp wird gelöscht.
# cancellation-bg-435.tmp wird gelöscht.
# cancellation-bg-437.tmp wird gelöscht.
# cancellation-bg-439.tmp wird gelöscht.
# cancellation-bg-441.tmp wird gelöscht.
# cancellation-bg-443.tmp wird gelöscht.
# cancellation-bg-445.tmp wird gelöscht.
# cancellation-bg-447.tmp wird gelöscht.
# cancellation-bg-449.tmp wird gelöscht.
# cancellation-bg-45.tmp wird gelöscht.
# cancellation-bg-451.tmp wird gelöscht.
# cancellation-bg-453.tmp wird gelöscht.
# cancellation-bg-455.tmp wird gelöscht.
# cancellation-bg-457.tmp wird gelöscht.
# cancellation-bg-459.tmp wird gelöscht.
# cancellation-bg-461.tmp wird gelöscht.
# cancellation-bg-463.tmp wird gelöscht.
# cancellation-bg-465.tmp wird gelöscht.
# cancellation-bg-467.tmp wird gelöscht.
# cancellation-bg-469.tmp wird gelöscht.
# cancellation-bg-47.tmp wird gelöscht.
# cancellation-bg-471.tmp wird gelöscht.
# cancellation-bg-473.tmp wird gelöscht.
# cancellation-bg-475.tmp wird gelöscht.
# cancellation-bg-477.tmp wird gelöscht.
# cancellation-bg-479.tmp wird gelöscht.
# cancellation-bg-481.tmp wird gelöscht.
# cancellation-bg-483.tmp wird gelöscht.
# cancellation-bg-485.tmp wird gelöscht.
# cancellation-bg-487.tmp wird gelöscht.
# cancellation-bg-489.tmp wird gelöscht.
# cancellation-bg-49.tmp wird gelöscht.
# cancellation-bg-491.tmp wird gelöscht.
# cancellation-bg-493.tmp wird gelöscht.
# cancellation-bg-495.tmp wird gelöscht.
# cancellation-bg-497.tmp wird gelöscht.
# cancellation-bg-499.tmp wird gelöscht.
# cancellation-bg-5.tmp wird gelöscht.
# cancellation-bg-501.tmp wird gelöscht.
# cancellation-bg-503.tmp wird gelöscht.
# cancellation-bg-505.tmp wird gelöscht.
# cancellation-bg-507.tmp wird gelöscht.
# cancellation-bg-509.tmp wird gelöscht.
# cancellation-bg-51.tmp wird gelöscht.
# cancellation-bg-511.tmp wird gelöscht.
# cancellation-bg-513.tmp wird gelöscht.
# cancellation-bg-515.tmp wird gelöscht.
# cancellation-bg-517.tmp wird gelöscht.
# cancellation-bg-519.tmp wird gelöscht.
# cancellation-bg-521.tmp wird gelöscht.
# cancellation-bg-523.tmp wird gelöscht.
# cancellation-bg-525.tmp wird gelöscht.
# cancellation-bg-527.tmp wird gelöscht.
# cancellation-bg-529.tmp wird gelöscht.
# cancellation-bg-53.tmp wird gelöscht.
# cancellation-bg-531.tmp wird gelöscht.
# cancellation-bg-533.tmp wird gelöscht.
# cancellation-bg-535.tmp wird gelöscht.
# cancellation-bg-537.tmp wird gelöscht.
# cancellation-bg-539.tmp wird gelöscht.
# cancellation-bg-541.tmp wird gelöscht.
# cancellation-bg-543.tmp wird gelöscht.
# cancellation-bg-545.tmp wird gelöscht.
# cancellation-bg-547.tmp wird gelöscht.
# cancellation-bg-549.tmp wird gelöscht.
# cancellation-bg-55.tmp wird gelöscht.
# cancellation-bg-551.tmp wird gelöscht.
# cancellation-bg-553.tmp wird gelöscht.
# cancellation-bg-555.tmp wird gelöscht.
# cancellation-bg-557.tmp wird gelöscht.
# cancellation-bg-559.tmp wird gelöscht.
# cancellation-bg-561.tmp wird gelöscht.
# cancellation-bg-563.tmp wird gelöscht.
# cancellation-bg-565.tmp wird gelöscht.
# cancellation-bg-567.tmp wird gelöscht.
# cancellation-bg-569.tmp wird gelöscht.
# cancellation-bg-57.tmp wird gelöscht.
# cancellation-bg-571.tmp wird gelöscht.
# cancellation-bg-573.tmp wird gelöscht.
# cancellation-bg-575.tmp wird gelöscht.
# cancellation-bg-577.tmp wird gelöscht.
# cancellation-bg-579.tmp wird gelöscht.
# cancellation-bg-581.tmp wird gelöscht.
# cancellation-bg-583.tmp wird gelöscht.
# cancellation-bg-585.tmp wird gelöscht.
# cancellation-bg-587.tmp wird gelöscht.
# cancellation-bg-589.tmp wird gelöscht.
# cancellation-bg-59.tmp wird gelöscht.
# cancellation-bg-591.tmp wird gelöscht.
# cancellation-bg-593.tmp wird gelöscht.
# cancellation-bg-595.tmp wird gelöscht.
# cancellation-bg-597.tmp wird gelöscht.
# cancellation-bg-599.tmp wird gelöscht.
# cancellation-bg-601.tmp wird gelöscht.
# cancellation-bg-603.tmp wird gelöscht.
# cancellation-bg-605.tmp wird gelöscht.
# cancellation-bg-607.tmp wird gelöscht.
# cancellation-bg-609.tmp wird gelöscht.
# cancellation-bg-61.tmp wird gelöscht.
# cancellation-bg-611.tmp wird gelöscht.
# cancellation-bg-613.tmp wird gelöscht.
# cancellation-bg-615.tmp wird gelöscht.
# cancellation-bg-617.tmp wird gelöscht.
# cancellation-bg-619.tmp wird gelöscht.
# cancellation-bg-621.tmp wird gelöscht.
# cancellation-bg-623.tmp wird gelöscht.
# cancellation-bg-625.tmp wird gelöscht.
# cancellation-bg-627.tmp wird gelöscht.
# cancellation-bg-629.tmp wird gelöscht.
# cancellation-bg-63.tmp wird gelöscht.
# cancellation-bg-631.tmp wird gelöscht.
# cancellation-bg-633.tmp wird gelöscht.
# cancellation-bg-635.tmp wird gelöscht.
# cancellation-bg-637.tmp wird gelöscht.
# cancellation-bg-639.tmp wird gelöscht.
# cancellation-bg-641.tmp wird gelöscht.
# cancellation-bg-643.tmp wird gelöscht.
# cancellation-bg-645.tmp wird gelöscht.
# cancellation-bg-647.tmp wird gelöscht.
# cancellation-bg-649.tmp wird gelöscht.
# cancellation-bg-65.tmp wird gelöscht.
# cancellation-bg-651.tmp wird gelöscht.
# cancellation-bg-653.tmp wird gelöscht.
# cancellation-bg-655.tmp wird gelöscht.
# cancellation-bg-657.tmp wird gelöscht.
# cancellation-bg-659.tmp wird gelöscht.
# cancellation-bg-661.tmp wird gelöscht.
# cancellation-bg-663.tmp wird gelöscht.
# cancellation-bg-665.tmp wird gelöscht.
# cancellation-bg-667.tmp wird gelöscht.
# cancellation-bg-669.tmp wird gelöscht.
# cancellation-bg-67.tmp wird gelöscht.
# cancellation-bg-671.tmp wird gelöscht.
# cancellation-bg-673.tmp wird gelöscht.
# cancellation-bg-675.tmp wird gelöscht.
# cancellation-bg-677.tmp wird gelöscht.
# cancellation-bg-679.tmp wird gelöscht.
# cancellation-bg-681.tmp wird gelöscht.
# cancellation-bg-683.tmp wird gelöscht.
# cancellation-bg-685.tmp wird gelöscht.
# cancellation-bg-687.tmp wird gelöscht.
# cancellation-bg-689.tmp wird gelöscht.
# cancellation-bg-69.tmp wird gelöscht.
# cancellation-bg-691.tmp wird gelöscht.
# cancellation-bg-693.tmp wird gelöscht.
# cancellation-bg-695.tmp wird gelöscht.
# cancellation-bg-697.tmp wird gelöscht.
# cancellation-bg-699.tmp wird gelöscht.
# cancellation-bg-7.tmp wird gelöscht.
# cancellation-bg-701.tmp wird gelöscht.
# cancellation-bg-703.tmp wird gelöscht.
# cancellation-bg-705.tmp wird gelöscht.
# cancellation-bg-707.tmp wird gelöscht.
# cancellation-bg-709.tmp wird gelöscht.
# cancellation-bg-71.tmp wird gelöscht.
# cancellation-bg-711.tmp wird gelöscht.
# cancellation-bg-713.tmp wird gelöscht.
# cancellation-bg-715.tmp wird gelöscht.
# cancellation-bg-717.tmp wird gelöscht.
# cancellation-bg-719.tmp wird gelöscht.
# cancellation-bg-721.tmp wird gelöscht.
# cancellation-bg-723.tmp wird gelöscht.
# cancellation-bg-725.tmp wird gelöscht.
# cancellation-bg-727.tmp wird gelöscht.
# cancellation-bg-729.tmp wird gelöscht.
# cancellation-bg-73.tmp wird gelöscht.
# cancellation-bg-731.tmp wird gelöscht.
# cancellation-bg-733.tmp wird gelöscht.
# cancellation-bg-735.tmp wird gelöscht.
# cancellation-bg-737.tmp wird gelöscht.
# cancellation-bg-739.tmp wird gelöscht.
# cancellation-bg-741.tmp wird gelöscht.
# cancellation-bg-743.tmp wird gelöscht.
# cancellation-bg-745.tmp wird gelöscht.
# cancellation-bg-747.tmp wird gelöscht.
# cancellation-bg-749.tmp wird gelöscht.
# cancellation-bg-75.tmp wird gelöscht.
# cancellation-bg-751.tmp wird gelöscht.
# cancellation-bg-753.tmp wird gelöscht.
# cancellation-bg-755.tmp wird gelöscht.
# cancellation-bg-757.tmp wird gelöscht.
# cancellation-bg-759.tmp wird gelöscht.
# cancellation-bg-761.tmp wird gelöscht.
# cancellation-bg-763.tmp wird gelöscht.
# cancellation-bg-765.tmp wird gelöscht.
# cancellation-bg-767.tmp wird gelöscht.
# cancellation-bg-769.tmp wird gelöscht.
# cancellation-bg-77.tmp wird gelöscht.
# cancellation-bg-771.tmp wird gelöscht.
# cancellation-bg-773.tmp wird gelöscht.
# cancellation-bg-775.tmp wird gelöscht.
# cancellation-bg-777.tmp wird gelöscht.
# cancellation-bg-779.tmp wird gelöscht.
# cancellation-bg-781.tmp wird gelöscht.
# cancellation-bg-783.tmp wird gelöscht.
# cancellation-bg-785.tmp wird gelöscht.
# cancellation-bg-787.tmp wird gelöscht.
# cancellation-bg-789.tmp wird gelöscht.
# cancellation-bg-79.tmp wird gelöscht.
# cancellation-bg-791.tmp wird gelöscht.
# cancellation-bg-793.tmp wird gelöscht.
# cancellation-bg-795.tmp wird gelöscht.
# cancellation-bg-797.tmp wird gelöscht.
# cancellation-bg-799.tmp wird gelöscht.
# cancellation-bg-801.tmp wird gelöscht.
# cancellation-bg-803.tmp wird gelöscht.
# cancellation-bg-805.tmp wird gelöscht.
# cancellation-bg-807.tmp wird gelöscht.
# cancellation-bg-809.tmp wird gelöscht.
# cancellation-bg-81.tmp wird gelöscht.
# cancellation-bg-811.tmp wird gelöscht.
# cancellation-bg-813.tmp wird gelöscht.
# cancellation-bg-815.tmp wird gelöscht.
# cancellation-bg-817.tmp wird gelöscht.
# cancellation-bg-819.tmp wird gelöscht.
# cancellation-bg-821.tmp wird gelöscht.
# cancellation-bg-823.tmp wird gelöscht.
# cancellation-bg-825.tmp wird gelöscht.
# cancellation-bg-827.tmp wird gelöscht.
# cancellation-bg-829.tmp wird gelöscht.
# cancellation-bg-83.tmp wird gelöscht.
# cancellation-bg-831.tmp wird gelöscht.
# cancellation-bg-833.tmp wird gelöscht.
# cancellation-bg-835.tmp wird gelöscht.
# cancellation-bg-837.tmp wird gelöscht.
# cancellation-bg-839.tmp wird gelöscht.
# cancellation-bg-841.tmp wird gelöscht.
# cancellation-bg-843.tmp wird gelöscht.
# cancellation-bg-845.tmp wird gelöscht.
# cancellation-bg-847.tmp wird gelöscht.
# cancellation-bg-849.tmp wird gelöscht.
# cancellation-bg-85.tmp wird gelöscht.
# cancellation-bg-851.tmp wird gelöscht.
# cancellation-bg-853.tmp wird gelöscht.
# cancellation-bg-855.tmp wird gelöscht.
# cancellation-bg-857.tmp wird gelöscht.
# cancellation-bg-859.tmp wird gelöscht.
# cancellation-bg-861.tmp wird gelöscht.
# cancellation-bg-863.tmp wird gelöscht.
# cancellation-bg-865.tmp wird gelöscht.
# cancellation-bg-867.tmp wird gelöscht.
# cancellation-bg-869.tmp wird gelöscht.
# cancellation-bg-87.tmp wird gelöscht.
# cancellation-bg-871.tmp wird gelöscht.
# cancellation-bg-873.tmp wird gelöscht.
# cancellation-bg-875.tmp wird gelöscht.
# cancellation-bg-877.tmp wird gelöscht.
# cancellation-bg-879.tmp wird gelöscht.
# cancellation-bg-881.tmp wird gelöscht.
# cancellation-bg-883.tmp wird gelöscht.
# cancellation-bg-885.tmp wird gelöscht.
# cancellation-bg-887.tmp wird gelöscht.
# cancellation-bg-889.tmp wird gelöscht.
# cancellation-bg-89.tmp wird gelöscht.
# cancellation-bg-891.tmp wird gelöscht.
# cancellation-bg-893.tmp wird gelöscht.
# cancellation-bg-895.tmp wird gelöscht.
# cancellation-bg-897.tmp wird gelöscht.
# cancellation-bg-899.tmp wird gelöscht.
# cancellation-bg-9.tmp wird gelöscht.
# cancellation-bg-901.tmp wird gelöscht.
# cancellation-bg-903.tmp wird gelöscht.
# cancellation-bg-905.tmp wird gelöscht.
# cancellation-bg-907.tmp wird gelöscht.
# cancellation-bg-909.tmp wird gelöscht.
# cancellation-bg-91.tmp wird gelöscht.
# cancellation-bg-911.tmp wird gelöscht.
# cancellation-bg-913.tmp wird gelöscht.
# cancellation-bg-915.tmp wird gelöscht.
# cancellation-bg-917.tmp wird gelöscht.
# cancellation-bg-919.tmp wird gelöscht.
# cancellation-bg-921.tmp wird gelöscht.
# cancellation-bg-923.tmp wird gelöscht.
# cancellation-bg-925.tmp wird gelöscht.
# cancellation-bg-927.tmp wird gelöscht.
# cancellation-bg-929.tmp wird gelöscht.
# cancellation-bg-93.tmp wird gelöscht.
# cancellation-bg-931.tmp wird gelöscht.
# cancellation-bg-933.tmp wird gelöscht.
# cancellation-bg-935.tmp wird gelöscht.
# cancellation-bg-937.tmp wird gelöscht.
# cancellation-bg-939.tmp wird gelöscht.
# cancellation-bg-941.tmp wird gelöscht.
# cancellation-bg-943.tmp wird gelöscht.
# cancellation-bg-945.tmp wird gelöscht.
# cancellation-bg-947.tmp wird gelöscht.
# cancellation-bg-949.tmp wird gelöscht.
# cancellation-bg-95.tmp wird gelöscht.
# cancellation-bg-951.tmp wird gelöscht.
# cancellation-bg-953.tmp wird gelöscht.
# cancellation-bg-955.tmp wird gelöscht.
# cancellation-bg-957.tmp wird gelöscht.
# cancellation-bg-959.tmp wird gelöscht.
# cancellation-bg-961.tmp wird gelöscht.
# cancellation-bg-963.tmp wird gelöscht.
# cancellation-bg-965.tmp wird gelöscht.
# cancellation-bg-967.tmp wird gelöscht.
# cancellation-bg-969.tmp wird gelöscht.
# cancellation-bg-97.tmp wird gelöscht.
# cancellation-bg-971.tmp wird gelöscht.
# cancellation-bg-973.tmp wird gelöscht.
# cancellation-bg-975.tmp wird gelöscht.
# cancellation-bg-977.tmp wird gelöscht.
# cancellation-bg-979.tmp wird gelöscht.
# cancellation-bg-981.tmp wird gelöscht.
# cancellation-bg-983.tmp wird gelöscht.
# cancellation-bg-985.tmp wird gelöscht.
# cancellation-bg-987.tmp wird gelöscht.
# cancellation-bg-989.tmp wird gelöscht.
# cancellation-bg-99.tmp wird gelöscht.
# cancellation-bg-991.tmp wird gelöscht.
# cancellation-bg-993.tmp wird gelöscht.
# cancellation-bg-995.tmp wird gelöscht.
# cancellation-bg-997.tmp wird gelöscht.
# cancellation-bg-999.tmp wird gelöscht.

# %% [markdown]
# ## Schritt 4 – Dateien löschen
#
# ### Theorie:
# Mit os.remove() können Dateien gelöscht werden.
#
# ### Beispielcode:
# ```python
# os.remove(os.path.join(root, file))
# print(f"{file} gelöscht.")
# ```
#
# ### Übung:
# 1. Ergänze deinen Code so, dass gefundene .tmp- und .log-Dateien tatsächlich gelöscht werden.
# 2. Überprüfe im Explorer, ob die Dateien wirklich verschwunden sind.

# %%
import os

targetdir = 'C:\\Users\\mytq\\AppData\\Local\\Temp'

for root, dirs, files in os.walk(targetdir):
    for file in files:
        if file.endswith('.tmp') or file.endswith('.log'):
            os.remove(os.path.join(root, file))
            print(f'{file} gelöscht.')

# %% [markdown]
# ## Schritt 5 – Fehler abfangen
#
# ### Theorie:
# Falls eine Datei gerade gesperrt ist, soll das Programm nicht abstürzen.
#
# ### Beispielcode:
# ```python
# try:
#     os.remove(os.path.join(root, file))
#     print(f"{file} gelöscht.")
# except Exception as e:
#     print(f"Fehler beim Löschen von {file}: {e}")
# ```
#
# ### Übung:
# 1. Provoziere einen Fehler (z. B. öffne eine .log-Datei in einem Editor und lasse das Programm laufen).
# 2. Stelle sicher, dass das Programm nicht abstürzt, sondern eine Fehlermeldung ausgibt.

# %%
import os

targetdir = 'C:\\Users\\mytq\\AppData\\Local\\Temp'

for root, dirs, files in os.walk(targetdir):
    for file in files:
        if file.endswith('.tmp') or file.endswith('.log'):
            try:
                os.remove(os.path.join(root, file))
                print(f'{file} gelöscht.')
            except Exception as e:
                print(f'Fehler beim Löschen von {file}: {e}')

# %% [markdown]
# ## Erweiterungsideen
# - Schreibe ein Logfile (cleanup.log), in dem alle gelöschten Dateien protokolliert werden.
# - Ergänze eine Eingabe (input()), damit der Benutzer den Zielordner selbst eingeben kann.
# - Baue ein Menü mit zwei Optionen:
#    1. „Cleanup starten“
#    2. „Log anzeigen“
